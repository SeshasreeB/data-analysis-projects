# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv("clinic_visits.csv")

# %%
df.shape

# %%
df["visit_id"] = df["visit_id"].astype(str)

# %%
df["wait_time_min"].value_counts(dropna=False)
#no na's in the columns

# %%
df.sort_values("wait_time_min")

# %%
df[df["insurance_type"] == "Medicare"]

# %%
df[(df["age"] >= 65) | (df["visit_type"] == "New patient")]

# %%
df[(df["wait_time_min"] > 40) & (df["visit_type"] == "Acute")]["wait_time_min"].describe()
#Try writing a filter to find all of the “Acute” visits where the wait time was over 40 minutes.

# %%
df.iloc[0]
# Out:
# visit_id                                    1001
# patient_id                                   602
# age                                           67
# gender                                         M
# visit_date         2024-01-28T00:00:00.000000000
# visit_type                             Follow-up
# wait_time_min                               19.0
# billing_amount                            263.88
# diagnosis                                Healthy
# provider_id                                 P103
# insurance_type                           Private
# is_return_visit                             True
# systolic_bp                                129.0
# diastolic_bp                                  88
# pain_score                                   7.0
# Name: 0, dtype: object
